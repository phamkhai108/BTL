# %%
import requests
import nltk
from underthesea import word_tokenize
from bs4 import BeautifulSoup

# URL của trang web
url = "https://vnexpress.net/"

# Sử dụng requests để tải nội dung trang web
response = requests.get(url)

# Kiểm tra xem việc tải nội dung thành công hay không
if response.status_code == 200:
    # Lấy nội dung HTML của trang web
    html = response.text

    # Tạo một đối tượng BeautifulSoup để phân tích nội dung HTML
    soup = BeautifulSoup(html, "html.parser")

    # Trích xuất văn bản từ trang web và loại bỏ các đoạn trống
    text = '\n'.join([line.strip() for line in soup.stripped_strings])

    #chuyển thành chữ thường
    def text_lower():
        text_lowers = text.lower()
        print(text_lowers)
        return text_lowers

    #loại bỏ các dấu câu
    def text_replace():
        # print(text.replace(".", "").replace(",", ""))
        text_replace = text.lower().replace(".", "").replace(",", "")
        return text_replace,  print(text_replace)

    #loại bỏ từ "dừng"
    def replace_words():
        print(text.replace("dừng", ""))

    #loại bỏ hoặc thay thế một từ bất kì 
    def replace_word():
        word = input("nhập từ cần loại bỏ theo định dạng chữ thường: ")
        replace = input("nhập từ cần thay thế: ")
        return "Đã thay thế", word, replace

    #tác từ
    def word_separation(word, replace, text_lowers):
        if word not in text_lowers: 
            print("Không tìm thấy từ muốn thay thế")
        else:
            print(word_tokenize(text.lower().replace(".", "").replace(',', '').replace("dừng", "").replace(word, replace)))


else:
    print("Không thể tải trang web.")

text_lower()
# Out:
# vnexpress - báo tiếng việt nhiều người xem nhất
# thứ ba, 28/11/2023
# mới nhất
# tin theo khu vực
# hà nội
# tp hồ chí minh
# international
# mới nhất
# thời sự
# góc nhìn
# thế giới
# video
# podcasts
# kinh doanh
# bất động sản
# khoa học
# giải trí
# thể thao
# pháp luật
# giáo dục
# sức khỏe
# đời sống
# du lịch
# số hóa
# xe
# ý kiến
# tâm sự
# thư giãn
# tất cả
# chủ tịch nước cùng thống đốc tokyo thưởng thức bánh mì việt
# chủ tịch nước võ văn thưởng cùng thống đốc tokyo thưởng thức ẩm thực việt nam tại nhà hàng bánh mì của hai cựu lưu học sinh gốc quảng nam ở thủ đô nhật.
# chủ tịch nước võ văn thưởng cùng phu nhân, thống đốc tokyo koike yuriko và lãnh đạo các tập đoàn lớn của nhật bản sáng nay đến nhà hàng "bánh mì xin chào" ở tokyo, thưởng thức các món ăn việt nam như bánh mì, mì quảng, phở, cà phê, gỏi cuốn, chè."bánh mì xin chào" là nhà hàng do hai cựu lưu học
# chất lượng không khí hà nội rất xấu
# nhiều tài xế 'đối phó' khi bị đo nồng độ cồn
# góc nhìn
# ...
